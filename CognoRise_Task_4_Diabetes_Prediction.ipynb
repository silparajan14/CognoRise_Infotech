# %% [markdown]
# # DIABETES PREDICTION

# %% [markdown]
#  Predict whether a person has diabetes or not using features like
# glucose levels and BMI.

# %%
import pandas as pd

#for removing warnings:
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/diabetes_prediction_dataset.csv')
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
df.tail()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %%
df.describe(include='O')
# Out:
#         gender smoking_history
# count   100000          100000
# unique       3               6
# top     Female         No Info
# freq     58552           35816

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
print("Shape of DataSet : ",df.shape)
# Out:
# Shape of DataSet :  (100000, 9)

# %% [markdown]
# Data Cleaning :

# %%
# check for duplicate rows:
df.duplicated().sum()
# Out:
# 3854

# %%
#drop duplicates:
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (96146, 9)

# %%
#checking for missing values :
df.isna().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99994  Female  36.0             0              0         No Info  24.60
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
#to change index :
df.reset_index(drop = True,inplace=True)

# %%
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 96141  Female  36.0             0              0         No Info  24.60
# 96142  Female   2.0             0              0         No Info  17.37
# 96143    Male  66.0             0              0          former  27.83
# 96144  Female  24.0             0              0           never  35.42
# 96145  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
#checking datatype of each columns :
df.dtypes
# Out:
# gender                  object
# age                    float64
# hypertension             int64
# heart_disease            int64
# smoking_history         object
# bmi                    float64
# HbA1c_level            float64
# blood_glucose_level      int64
# diabetes                 int64
# dtype: object

# %%
#checking total counts of target column :
df['diabetes'].value_counts()
# Out:
# 0    87664
# 1     8482
# Name: diabetes, dtype: int64

# %%
#to convert categorical variables into numerical format we are using LabelEncoder :
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

df['gender'] = le.fit_transform(df['gender'])
df['smoking_history'] = le.fit_transform(df['smoking_history'])

# %%
df.dtypes
# Out:
# gender                   int64
# age                    float64
# hypertension             int64
# heart_disease            int64
# smoking_history          int64
# bmi                    float64
# HbA1c_level            float64
# blood_glucose_level      int64
# diabetes                 int64
# dtype: object

# %% [markdown]
# Developing Models :

# %%
# Splitting data :

X = df.iloc[:,:-1]
X
# Out:
#        gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0           0  80.0             0              1                4  25.19
# 1           0  54.0             0              0                0  27.32
# 2           1  28.0             0              0                4  27.32
# 3           0  36.0             0              0                1  23.45
# 4           1  76.0             1              1                1  20.14
# ...       ...   ...           ...            ...              ...    ...
# 96141       0  36.0             0              0                0  24.60
# 96142       0   2.0             0              0                0  17.37
# 96143       1  66.0             0              0                3  27.83
# 96144       0  24.0             0              0                4  35.42
# 96145       0  57.0             0              0                1  22.43
#
#        HbA1c_level  blood_glucose_level
# 0              6.6                  140
# ...

# %%
y = df.iloc[:,-1]
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 96141    0
# 96142    0
# 96143    0
# 96144    0
# 96145    0
# Name: diabetes, Length: 96146, dtype: int64

# %% [markdown]
# Applying StandardScaler and then Train Test Split :

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
X
# Out:
# array([[-8.43459189e-01,  1.70083970e+00, -2.90050377e-01, ...,
#         -3.14947071e-01,  9.94562951e-01,  4.35538650e-02],
#        [-8.43459189e-01,  5.43372045e-01, -2.90050377e-01, ...,
#         -2.15895425e-04,  9.94562951e-01, -1.42309603e+00],
#        [ 1.18376945e+00, -6.14095608e-01, -2.90050377e-01, ...,
#         -2.15895425e-04,  1.55970122e-01,  4.83548835e-01],
#        ...,
#        [ 1.18376945e+00,  1.07758788e+00, -2.90050377e-01, ...,
#          7.51422735e-02,  1.55970122e-01,  4.10216340e-01],
#        [-8.43459189e-01, -7.92167555e-01, -2.90050377e-01, ...,
#          1.19664914e+00, -1.42803856e+00, -9.34212734e-01],
#        [-8.43459189e-01,  6.76926005e-01, -2.90050377e-01, ...,
#         -7.22767750e-01,  9.94562951e-01, -1.17865438e+00]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3, random_state = 1)

# %%
#checking shapes of each test sets :
print("Shape of X train : ",X_train.shape)
print("Shape of X test : ",X_test.shape)
print("Shape of y train : ",y_train.shape)
print("Shape of y test : ",y_test.shape)
# Out:
# Shape of X train :  (67302, 8)
# Shape of X test :  (28844, 8)
# Shape of y train :  (67302,)
# Shape of y test :  (28844,)

# %% [markdown]
# Classifiers

# %% [markdown]
# Importing necessary libraries and applying different algorithms all at the same time using for loop :

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier


from sklearn.metrics import ConfusionMatrixDisplay, classification_report

rf = RandomForestClassifier(random_state=13)
knn = KNeighborsClassifier(n_neighbors = 5)
ad = AdaBoostClassifier(random_state = 13)
deci = DecisionTreeClassifier(random_state=13)


models = [rf,knn,ad,deci]

for model in models:
  print("********************************",model,"********************************")
  model.fit(X_train,y_train)
  y_pred = model.predict(X_test)
  print(classification_report(y_test,y_pred))
  print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))
# Out:
# ******************************** RandomForestClassifier(random_state=13) ********************************
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98     26236
#            1       0.95      0.67      0.79      2608
#
#     accuracy                           0.97     28844
#    macro avg       0.96      0.83      0.88     28844
# weighted avg       0.97      0.97      0.96     28844
#
# ...
# ******************************** KNeighborsClassifier() ********************************
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98     26236
#            1       0.90      0.61      0.73      2608
#
#     accuracy                           0.96     28844
#    macro avg       0.93      0.80      0.85     28844
# weighted avg       0.96      0.96      0.95     28844
#
# ...
# ******************************** AdaBoostClassifier(random_state=13) ********************************
# ...

# %% [markdown]
# Regressors

# %%
from sklearn.metrics import accuracy_score, mean_absolute_error,mean_squared_error,r2_score
import numpy as np

from sklearn.linear_model import LinearRegression

lir = LinearRegression()

lir.fit(X_train,y_train)
y_pred = knn.predict(X_test)

print("R2_score : ",r2_score(y_test,y_pred)*100)
print("MeanAbsoluteError : ",mean_absolute_error(y_test,y_pred))
print("MeanSquaredError : ",mean_squared_error(y_test,y_pred))
print("RootMeanSquaredError : ",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2_score :  49.456017208593636
# MeanAbsoluteError :  0.04156843710997088
# MeanSquaredError :  0.04156843710997088
# RootMeanSquaredError :  0.20388339096152702

# %% [markdown]
# Checking if our models can predict a new set of data correctly :

# %%
rf = RandomForestClassifier(random_state=13)
knn = KNeighborsClassifier(n_neighbors = 5)
ad = AdaBoostClassifier(random_state = 13)
deci = DecisionTreeClassifier(random_state=13)
lir = LinearRegression()

models = [rf,knn,ad,deci,lir]

for model in models :
  print(model)
  model.fit(X_train,y_train)
  y_pred = model.predict(X_test)
  y_pred_new = model.predict(sc.transform([[0,80.0,0,1,4,25.19,6.6,140]]))
  print(y_pred_new)
# Out:
# RandomForestClassifier(random_state=13)
# [0]
# KNeighborsClassifier()
# [0]
# AdaBoostClassifier(random_state=13)
# [0]
# DecisionTreeClassifier(random_state=13)
# [0]
# LinearRegression()
# [0.32691349]

# %% [markdown]
# All our models predicted correctly

# %% [markdown]
# Here the samples are unevenly distributed

# %% [markdown]
# *OVER SAMPLING*

# %%
from imblearn.over_sampling import SMOTE
os = SMOTE(random_state = 1)
X_os,y_os = os.fit_resample(X,y)

# %%
y_os.value_counts()
# Out:
# 0    87664
# 1    87664
# Name: diabetes, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X_os,y_os,test_size = 0.3,random_state=1)

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
rf_os = RandomForestClassifier(random_state=13)
knn_os = KNeighborsClassifier(n_neighbors = 5)
ad_os = AdaBoostClassifier(random_state = 13)
deci_os = DecisionTreeClassifier(random_state=13)


models = [rf_os,knn_os,ad_os,deci_os]

for model in models:
  print("********************************",model,"********************************")
  model.fit(X_train,y_train)
  y_pred_os = model.predict(X_test)
  print(classification_report(y_test,y_pred_os))
  print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred_os))
# Out:
# ******************************** RandomForestClassifier(random_state=13) ********************************
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     26365
#            1       0.98      0.98      0.98     26234
#
#     accuracy                           0.98     52599
#    macro avg       0.98      0.98      0.98     52599
# weighted avg       0.98      0.98      0.98     52599
#
# ...
# ******************************** KNeighborsClassifier() ********************************
#               precision    recall  f1-score   support
#
#            0       0.98      0.91      0.95     26365
#            1       0.92      0.99      0.95     26234
#
#     accuracy                           0.95     52599
#    macro avg       0.95      0.95      0.95     52599
# weighted avg       0.95      0.95      0.95     52599
#
# ...
# ******************************** AdaBoostClassifier(random_state=13) ********************************
# ...

# %% [markdown]
# *UNDER SAMPLING*

# %%
from imblearn.under_sampling import RandomUnderSampler
us = RandomUnderSampler(random_state = 1)
X_us,y_us = us.fit_resample(X,y)

# %%
y_us.value_counts()
# Out:
# 0    8482
# 1    8482
# Name: diabetes, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X_us,y_us,test_size = 0.3,random_state=1)

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
rf_us = RandomForestClassifier(random_state=13)
knn_us = KNeighborsClassifier(n_neighbors = 5)
ad_us = AdaBoostClassifier(random_state = 13)
deci_us = DecisionTreeClassifier(random_state=13)


models = [rf_us,knn_us,ad_us,deci_us]

for model in models:
  print("********************************",model,"********************************")
  model.fit(X_train,y_train)
  y_pred_us = model.predict(X_test)
  print(classification_report(y_test,y_pred_us))
  print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred_us))
# Out:
# ******************************** RandomForestClassifier(random_state=13) ********************************
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.89      2511
#            1       0.88      0.92      0.90      2579
#
#     accuracy                           0.90      5090
#    macro avg       0.90      0.90      0.90      5090
# weighted avg       0.90      0.90      0.90      5090
#
# ...
# ******************************** KNeighborsClassifier() ********************************
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87      2511
#            1       0.86      0.90      0.88      2579
#
#     accuracy                           0.87      5090
#    macro avg       0.87      0.87      0.87      5090
# weighted avg       0.87      0.87      0.87      5090
#
# ...
# ******************************** AdaBoostClassifier(random_state=13) ********************************
# ...
